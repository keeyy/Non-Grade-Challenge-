# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv(r'C:\Users\LENOVO\OneDrive\Documents\NGC\h8dsft_Descriptive\NGC10_Kezia Intan.csv')

# %%
df
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 31817  9/15/2022             ID-SA    Sulawesi Utara         37           0
# 31818  9/15/2022             ID-SB    Sumatera Barat         13           0
# 31819  9/15/2022             ID-SS  Sumatera Selatan         16           0
# 31820  9/15/2022             ID-SU    Sumatera Utara         50           0
# 31821  9/16/2022               IDN         Indonesia       2358          27
#
# ...

# %%
df.mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19404\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# New Cases                      4.023114e+02
# New Deaths                     9.920652e+00
# New Recovered                  3.903985e+02
# New Active Cases               1.992238e+00
# Total Cases                    1.594500e+05
# Total Deaths                   4.564753e+03
# Total Recovered                1.492615e+05
# Total Active Cases             5.623782e+03
# City or Regency                         NaN
# Total Regencies                2.402728e+01
# Total Cities                   5.835840e+00
# Total Districts                4.179523e+02
# Total Urban Villages           5.055139e+02
# ...

# %%
df.median()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19404\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# New Cases                      2.700000e+01
# New Deaths                     0.000000e+00
# New Recovered                  2.000000e+01
# New Active Cases               0.000000e+00
# Total Cases                    2.359650e+04
# Total Deaths                   5.655000e+02
# Total Recovered                2.102750e+04
# Total Active Cases             5.570000e+02
# City or Regency                         NaN
# Total Regencies                1.100000e+01
# Total Cities                   2.000000e+00
# Total Districts                1.690000e+02
# Total Urban Villages           1.750000e+02
# ...

# %%
df.mode()
# Out:
#           Date Location ISO Code     Location  New Cases  New Deaths  \
# 0     1/1/2021             ID-JK  DKI Jakarta        0.0         0.0
# 1     1/1/2022               IDN    Indonesia        NaN         NaN
# 2    1/10/2021               NaN          NaN        NaN         NaN
# 3    1/10/2022               NaN          NaN        NaN         NaN
# 4    1/11/2021               NaN          NaN        NaN         NaN
# ..         ...               ...          ...        ...         ...
# 883   9/8/2021               NaN          NaN        NaN         NaN
# 884   9/8/2022               NaN          NaN        NaN         NaN
# 885   9/9/2020               NaN          NaN        NaN         NaN
# 886   9/9/2021               NaN          NaN        NaN         NaN
# 887   9/9/2022               NaN          NaN        NaN         NaN
#
#      New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0.0               0.0          1.0           1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
numcols = df.select_dtypes(exclude='object').columns.tolist()
for col in numcols:
    print(df[col].name + 'range : ' + str(df[col].max() - df[col].min()))
# Out:
# New Casesrange : 64718
# New Deathsrange : 2069
# New Recoveredrange : 61361
# New Active Casesrange : 69103
# Total Casesrange : 6405043
# Total Deathsrange : 157876
# Total Recoveredrange : 6218708
# Total Active Casesrange : 588456
# City or Regencyrange : nan
# Total Regenciesrange : 415
# Total Citiesrange : 97.0
# Total Districtsrange : 7186
# Total Urban Villagesrange : 8453.0
# Total Rural Villagesrange : 74678.0
# Area (km2)range : 1916243
# Populationrange : 264537113
# Population Densityrange : 16325.72
# Longituderange : 41.785508260000015
# Latituderange : 12.907819627999999
# New Cases per Millionrange : 1459.04
# Total Cases per Millionrange : 130231.61
# New Deaths per Millionrange : 63.8
# Total Deaths per Millionrange : 1632.6
# Total Deaths per 100rbrange : 163.26
# Growth Factor of New Casesrange : 175.0
# Growth Factor of New Deathsrange : 134.5

# %%
df.describe()
# Out:
#           New Cases    New Deaths  New Recovered  New Active Cases  \
# count  31822.000000  31822.000000   31822.000000      31822.000000
# mean     402.311388      9.920652     390.398498          1.992238
# std     2320.629838     64.139080    2199.878802       1219.513355
# min        0.000000      0.000000       0.000000     -29938.000000
# 25%        3.000000      0.000000       2.000000        -12.000000
# 50%       27.000000      0.000000      20.000000          0.000000
# 75%      130.000000      3.000000     123.000000         19.000000
# max    64718.000000   2069.000000   61361.000000      39165.000000
#
#         Total Cases   Total Deaths  Total Recovered  Total Active Cases  \
# count  3.182200e+04   31822.000000     3.182200e+04        31822.000000
# mean   1.594500e+05    4564.753221     1.492615e+05         5623.782415
# std    6.264435e+05   17693.731369     5.958536e+05        28537.412305
# min    1.000000e+00       0.000000     0.000000e+00        -2343.000000
# ...

# %%
print(stats.percentileofscore(df[numcols], 37, kind='strict'))
# Out:
# nan

# %%
print(stats.percentileofscore(df[numcols], 37, kind='weak'))
# Out:
# nan

# %%
print(df[numcols].quantile([0.25, 0.5, 0.75]))
# Out:
#       New Cases  New Deaths  New Recovered  New Active Cases  Total Cases  \
# 0.25        3.0         0.0            2.0             -12.0      5223.25
# 0.50       27.0         0.0           20.0               0.0     23596.50
# 0.75      130.0         3.0          123.0              19.0     69927.75
#
#       Total Deaths  Total Recovered  Total Active Cases  City or Regency  \
# 0.25         128.0           3913.5                80.0              NaN
# 0.50         565.5          21027.5               557.0              NaN
# 0.75        2189.0          64142.0              2279.0              NaN
#
#       Total Regencies  ...  Population Density   Longitude  Latitude  \
# 0.25              7.0  ...               47.79  106.109004 -6.204699
# 0.50             11.0  ...              103.84  113.417654 -2.461746
# 0.75             18.0  ...              262.70  121.201093  0.212037
#
#       New Cases per Million  Total Cases per Million  New Deaths per Million  \
# ...

# %%
df[numcols].plot(kind='box', figsize=(10,10))
plt.show()

# %%
df['New Cases'].plot(kind='box',figsize=(10,10))
plt.show()

# %%
df[numcols].var()
# Out:
# New Cases                      5.385323e+06
# New Deaths                     4.113822e+03
# New Recovered                  4.839467e+06
# New Active Cases               1.487213e+06
# Total Cases                    3.924314e+11
# Total Deaths                   3.130681e+08
# Total Recovered                3.550415e+11
# Total Active Cases             8.143839e+08
# City or Regency                         NaN
# Total Regencies                4.673053e+03
# Total Cities                   2.686361e+02
# Total Districts                1.423237e+06
# Total Urban Villages           2.022286e+06
# Total Rural Villages           1.583253e+08
# Area (km2)                     1.016248e+11
# Population                     1.990689e+15
# Population Density             7.449797e+06
# Longitude                      9.726039e+01
# Latitude                       1.301813e+01
# New Cases per Million          5.521933e+03
# Total Cases per Million        2.715042e+08
# ...

# %%
df[numcols].std()
# Out:
# New Cases                      2.320630e+03
# New Deaths                     6.413908e+01
# New Recovered                  2.199879e+03
# New Active Cases               1.219513e+03
# Total Cases                    6.264435e+05
# Total Deaths                   1.769373e+04
# Total Recovered                5.958536e+05
# Total Active Cases             2.853741e+04
# City or Regency                         NaN
# Total Regencies                6.835973e+01
# Total Cities                   1.639012e+01
# Total Districts                1.192995e+03
# Total Urban Villages           1.422071e+03
# Total Rural Villages           1.258274e+04
# Area (km2)                     3.187865e+05
# Population                     4.461714e+07
# Population Density             2.729432e+03
# Longitude                      9.862068e+00
# Latitude                       3.608065e+00
# New Cases per Million          7.430971e+01
# Total Cases per Million        1.647739e+04
# ...
